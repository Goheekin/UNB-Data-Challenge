# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import klib

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ## Air Pollution Exposure Estimates 1990-2019

# %%
Df1 = pd.read_csv("Air Pollution Exposure Estimates 1990-2019/Data sets/IHME_GBD_2019_AIR_POLLUTION_1990_2019_HAP_Y2021M10D08 2.csv")
Df2 = pd.read_csv("Air Pollution Exposure Estimates 1990-2019/Data sets/IHME_GBD_2019_AIR_POLLUTION_1990_2019_LOCATION_HIERARCHIES_Y2021M10D08.csv")
Df3 = pd.read_csv("Air Pollution Exposure Estimates 1990-2019/Data sets/IHME_GBD_2019_AIR_POLLUTION_1990_2019_OZONE_Y2021M10D08.csv")
Df4 = pd.read_csv("Air Pollution Exposure Estimates 1990-2019/Data sets/IHME_GBD_2019_AIR_POLLUTION_1990_2019_PM_Y2021M10D08 2.csv")

# %%
Df1
# Out:
#        measure_id measure_name  location_id location_name  rei_id  \
# 0              18   Proportion            1        Global      87
# 1              18   Proportion            1        Global      87
# 2              18   Proportion            1        Global      87
# 3              18   Proportion            1        Global      87
# 4              18   Proportion            1        Global      87
# ...           ...          ...          ...           ...     ...
# 20635          18   Proportion        44792      Plymouth      87
# 20636          18   Proportion        44792      Plymouth      87
# 20637          18   Proportion        44792      Plymouth      87
# 20638          18   Proportion        44792      Plymouth      87
# 20639          18   Proportion        44792      Plymouth      87
#
#                                        rei_name  year_id      mean    median  \
# 0      Household air pollution from solid fuels     1990  0.654155  0.654173
# ...

# %%
Df1['location_name'].value_counts()
# Out:
# North Africa and Middle East    60
# South Asia                      60
# Georgia                         60
# India                           30
# African Region                  30
#                                 ..
# Yucatán                         30
# Kumamoto                        30
# Merton                          30
# Kwale                           30
# Nauru                           30
# Name: location_name, Length: 685, dtype: int64

# %%
## plot the mean with year id
import seaborn as sns

sns.lineplot(data=Df1, x = "year_id", y = "mean")
# Out:
# <AxesSubplot:xlabel='year_id', ylabel='mean'>

# %%
## plot the mean with year id
import seaborn as sns

sns.lineplot(data=Df1, x = "year_id", y = "population")
# Out:
# <AxesSubplot:xlabel='year_id', ylabel='population'>

# %%
# This code run to print bar chart
# The parameter in hist() used to adjust the number of bins and ranges 
# The parameter ticklabel_format() used to convert the population into whole number
plt.hist(Df1['population'], bins=80, range =[0, 3e6])
plt.suptitle('Population')
plt.ticklabel_format(style='plain')
plt.show()

# %%
Df2
# Out:
#      location_id                           location_name sdi_quintile  \
# 0              1                                  Global          NaN
# 1              4  Southeast Asia, East Asia, and Oceania          NaN
# 2              5                               East Asia          NaN
# 3              6                                   China          NaN
# 4              7   Democratic People's Republic of Korea  Low Mid SDI
# ..           ...                                     ...          ...
# 636        44788                                  Torbay     High SDI
# 637        44789                        Bristol, City of     High SDI
# 638        44790                             Bournemouth     High SDI
# 639        44791                                Cornwall     High SDI
# 640        44792                                Plymouth     High SDI
#
#     african_union              commonwealth              eu  \
# 0             NaN                       NaN             NaN
# ...

# %%
Df2.isnull().sum()
# Out:
# location_id             0
# location_name           0
# sdi_quintile           61
# african_union         544
# commonwealth          395
# eu                    462
# four_world_regions     72
# G20                   265
# OECD                  329
# WHO_regions            69
# WB_income              69
# WB_regions             70
# nordic                635
# dtype: int64

# %%
Df3
# Out:
#        measure_id measure_name  location_id location_name  rei_id  \
# 0              19   Continuous            1        Global      88
# 1              19   Continuous            1        Global      88
# 2              19   Continuous            1        Global      88
# 3              19   Continuous            1        Global      88
# 4              19   Continuous            1        Global      88
# ...           ...          ...          ...           ...     ...
# 20635          19   Continuous        44792      Plymouth      88
# 20636          19   Continuous        44792      Plymouth      88
# 20637          19   Continuous        44792      Plymouth      88
# 20638          19   Continuous        44792      Plymouth      88
# 20639          19   Continuous        44792      Plymouth      88
#
#                       rei_name  year_id unit       mean     median      upper  \
# 0      Ambient ozone pollution     1990  ppb  43.958706  43.957631  44.018968
# ...

# %%
## plot the mean with year id
import seaborn as sns

sns.lineplot(data=Df3, x = "year_id", y = "mean")
# Out:
# <AxesSubplot:xlabel='year_id', ylabel='mean'>

# %%
Df4
# Out:
#       measure_id measure_name  location_id location_name  rei_id  \
# 0             19   Continuous            1        Global      86
# 1             19   Continuous            1        Global      86
# 2             19   Continuous            1        Global      86
# 3             19   Continuous            1        Global      86
# 4             19   Continuous            1        Global      86
# ...          ...          ...          ...           ...     ...
# 9655          19   Continuous        44792      Plymouth      86
# 9656          19   Continuous        44792      Plymouth      86
# 9657          19   Continuous        44792      Plymouth      86
# 9658          19   Continuous        44792      Plymouth      86
# 9659          19   Continuous        44792      Plymouth      86
#
#                                   rei_name  year_id  \
# 0     Ambient particulate matter pollution     1990
# 1     Ambient particulate matter pollution     1995
# ...

# %%
## plot the mean with year id
import seaborn as sns

sns.lineplot(data=Df4, x = "year_id", y = "mean")
# Out:
# <AxesSubplot:xlabel='year_id', ylabel='mean'>

# %% [markdown]
# ## Smoking Tobacco Use Prevalence 1990-2019

# %%
Df1 = pd.read_csv("Smoking Tobacco Use Prevalence 1990-2019/Data sets/IHME_GBD_2019_SMOKING_TOB_1990_2019_CIG_PC_Y2021M05D27.csv")
Df2 = pd.read_csv("Smoking Tobacco Use Prevalence 1990-2019/Data sets/IHME_GBD_2019_SMOKING_TOB_1990_2019_NUM_SMOKERS_Y2021M05D27 2.csv")
Df3 = pd.read_csv("Smoking Tobacco Use Prevalence 1990-2019/Data sets/IHME_GBD_2019_SMOKING_TOB_1990_2019_PCT_CHANGE_Y2021M05D27.csv")
Df4 = pd.read_csv("Smoking Tobacco Use Prevalence 1990-2019/Data sets/IHME_GBD_2019_SMOKING_TOB_1990_2019_PREV_Y2021M05D27 3.csv")

# %%
Df1
# Out:
#                          measure_name  location_id  \
# 0    Cigarette-Equivalents Per Capita            1
# 1    Cigarette-Equivalents Per Capita            1
# 2    Cigarette-Equivalents Per Capita            4
# 3    Cigarette-Equivalents Per Capita            4
# 4    Cigarette-Equivalents Per Capita            5
# ..                                ...          ...
# 461  Cigarette-Equivalents Per Capita          422
# 462  Cigarette-Equivalents Per Capita          435
# 463  Cigarette-Equivalents Per Capita          435
# 464  Cigarette-Equivalents Per Capita          522
# 465  Cigarette-Equivalents Per Capita          522
#
#                               location_name  sex_id sex_name  age_group_id  \
# 0                                    Global       3     Both            29
# 1                                    Global       3     Both            29
# 2    Southeast Asia, East Asia, and Oceania       3     Both            29
# ...

# %%
Df2
# Out:
#             measure_name  location_id location_name  sex_id sex_name  \
# 0      Number of Smokers            1        Global       1     Male
# 1      Number of Smokers            1        Global       2   Female
# 2      Number of Smokers            1        Global       3     Both
# 3      Number of Smokers            1        Global       1     Male
# 4      Number of Smokers            1        Global       2   Female
# ...                  ...          ...           ...     ...      ...
# 20965  Number of Smokers          522         Sudan       2   Female
# 20966  Number of Smokers          522         Sudan       3     Both
# 20967  Number of Smokers          522         Sudan       1     Male
# 20968  Number of Smokers          522         Sudan       2   Female
# 20969  Number of Smokers          522         Sudan       3     Both
#
#        age_group_id age_group_name  year_id           val         upper  \
# ...

# %%
Df3
# Out:
#                                            measure_name  location_id  \
# 0              % Change in Number of Smokers, 1990-2019            1
# 1     % Change in Age-Standardized Smoking Prevalenc...            1
# 2              % Change in Number of Smokers, 1990-2019            1
# 3     % Change in Age-Standardized Smoking Prevalenc...            1
# 4              % Change in Number of Smokers, 1990-2019            1
# ...                                                 ...          ...
# 1393  % Change in Age-Standardized Smoking Prevalenc...          522
# 1394           % Change in Number of Smokers, 1990-2019          522
# 1395  % Change in Age-Standardized Smoking Prevalenc...          522
# 1396           % Change in Number of Smokers, 1990-2019          522
# 1397  % Change in Age-Standardized Smoking Prevalenc...          522
#
#      location_name  sex_id sex_name  age_group_id age_group_name       val  \
# ...

# %%
Df4
# Out:
#                               measure_name  location_id location_name  sex_id  \
# 0      Age-Standardized Smoking Prevalence            1        Global       1
# 1      Age-Standardized Smoking Prevalence            1        Global       2
# 2      Age-Standardized Smoking Prevalence            1        Global       3
# 3      Age-Standardized Smoking Prevalence            1        Global       1
# 4      Age-Standardized Smoking Prevalence            1        Global       2
# ...                                    ...          ...           ...     ...
# 20965  Age-Standardized Smoking Prevalence          522         Sudan       2
# 20966  Age-Standardized Smoking Prevalence          522         Sudan       3
# 20967  Age-Standardized Smoking Prevalence          522         Sudan       1
# 20968  Age-Standardized Smoking Prevalence          522         Sudan       2
# 20969  Age-Standardized Smoking Prevalence          522         Sudan       3
#
# ...

# %% [markdown]
# ## Under-5 Mortality and Adult Mortality 1950-2019

# %%
Df1 = pd.read_csv("Under-5 Mortality and Adult Mortality 1950-2019/Data sets/IHME_GBD_2019_MORTALITY_1950_2019_45Q15_NOSHOCK_Y2020M07D31.csv")
Df2 = pd.read_csv("Under-5 Mortality and Adult Mortality 1950-2019/Data sets/IHME_GBD_2019_MORTALITY_1950_2019_45Q15_WSHOCK_Y2020M11D13.csv")
Df3 = pd.read_csv("Under-5 Mortality and Adult Mortality 1950-2019/Data sets/IHME_GBD_2019_MORTALITY_1950_2019_5Q0_NOSHOCK_Y2020M07D31 2.csv")
Df4 = pd.read_csv("Under-5 Mortality and Adult Mortality 1950-2019/Data sets/IHME_GBD_2019_MORTALITY_1950_2019_5Q0_WSHOCK_Y2020M11D13.csv")

# %%
## measure_id only 33
Df1
# Out:
#         location_id location_name  sex_id sex_name  age_group_id  \
# 0                 1        Global       1     male           199
# 1                 1        Global       1     male           199
# 2                 1        Global       1     male           199
# 3                 1        Global       1     male           199
# 4                 1        Global       1     male           199
# ...             ...           ...     ...      ...           ...
# 141745        44792      Plymouth       3     both           199
# 141746        44792      Plymouth       3     both           199
# 141747        44792      Plymouth       3     both           199
# 141748        44792      Plymouth       3     both           199
# 141749        44792      Plymouth       3     both           199
#
#        age_group_name  year_id  measure_id  \
# 0            15 to 59     1950          33
# 1            15 to 59     1951          33
# 2            15 to 59     1952          33
# ...

# %%
## measure_id only 27
Df2
# Out:
#         location_id location_name  sex_id sex_name  age_group_id  \
# 0                 1        Global       1     male           199
# 1                 1        Global       2   female           199
# 2                 1        Global       3     both           199
# 3                 1        Global       1     male           199
# 4                 1        Global       2   female           199
# ...             ...           ...     ...      ...           ...
# 141745        44792      Plymouth       2   female           199
# 141746        44792      Plymouth       3     both           199
# 141747        44792      Plymouth       1     male           199
# 141748        44792      Plymouth       2   female           199
# 141749        44792      Plymouth       3     both           199
#
#        age_group_name  year_id  measure_id          measure_name  metric_id  \
# 0            15 to 59     1950          27  Probability of death          8
# ...

# %%
## measure_id only 33
Df3
# Out:
#         location_id location_name  sex_id sex_name  age_group_id  \
# 0                 1        Global       1     male             1
# 1                 1        Global       1     male             1
# 2                 1        Global       1     male             1
# 3                 1        Global       1     male             1
# 4                 1        Global       1     male             1
# ...             ...           ...     ...      ...           ...
# 141745        44792      Plymouth       3     both             1
# 141746        44792      Plymouth       3     both             1
# 141747        44792      Plymouth       3     both             1
# 141748        44792      Plymouth       3     both             1
# 141749        44792      Plymouth       3     both             1
#
#        age_group_name  year_id  measure_id  \
# 0             Under 5     1950          33
# 1             Under 5     1951          33
# 2             Under 5     1952          33
# ...

# %%
## measure_id only 27
Df4
# Out:
#         location_id location_name  sex_id sex_name  age_group_id  \
# 0                 1        Global       1     male             1
# 1                 1        Global       2   female             1
# 2                 1        Global       3     both             1
# 3                 1        Global       1     male             1
# 4                 1        Global       2   female             1
# ...             ...           ...     ...      ...           ...
# 141745        44792      Plymouth       2   female             1
# 141746        44792      Plymouth       3     both             1
# 141747        44792      Plymouth       1     male             1
# 141748        44792      Plymouth       2   female             1
# 141749        44792      Plymouth       3     both             1
#
#        age_group_name  year_id  measure_id          measure_name  metric_id  \
# 0             Under 5     1950          27  Probability of death          8
# ...

# %%
Df2['measure_id'].value_counts()
# Out:
# 27    141750
# Name: measure_id, dtype: int64
